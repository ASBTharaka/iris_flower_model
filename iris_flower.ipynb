# %% [markdown]
# <a href="https://colab.research.google.com/github/ASBTharaka/iris_flower_model/blob/main/iris_flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset= pd.read_csv('/content/drive/MyDrive/iris.csv')

# %%
print(dataset,dataset.shape)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns] (150, 5)

# %%
data=dataset.iloc[:,0:4]
print(data,data.shape)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns] (150, 4)

# %%
target=dataset.iloc[:,4]
print(target)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: variety, Length: 150, dtype: int64

# %%
import sklearn as sk
from sklearn.model_selection import train_test_split
train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.2)
print(train_data,train_data.shape)
print(test_data,test_data.shape)
print(train_target,train_target.shape)
print(test_target,test_target.shape)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 90            5.5          2.6           4.4          1.2
# 8             4.4          2.9           1.4          0.2
# 123           6.3          2.7           4.9          1.8
# 29            4.7          3.2           1.6          0.2
# 54            6.5          2.8           4.6          1.5
# ..            ...          ...           ...          ...
# 129           7.2          3.0           5.8          1.6
# 73            6.1          2.8           4.7          1.2
# 7             5.0          3.4           1.5          0.2
# 5             5.4          3.9           1.7          0.4
# 74            6.4          2.9           4.3          1.3
#
# [120 rows x 4 columns] (120, 4)
#      sepal.length  sepal.width  petal.length  petal.width
# 10            5.4          3.7           1.5          0.2
# 75            6.6          3.0           4.4          1.4
# 57            4.9          2.4           3.3          1.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
model =KNeighborsClassifier()
model.fit(train_data,train_target)
# Out:
# KNeighborsClassifier()

# %%
predicted_target=model.predict(test_data)
print(predicted_target)
# Out:
# [0 1 1 1 0 2 0 1 0 0 1 2 2 0 2 1 1 2 1 2 2 0 2 2 0 1 1 1 0 1]

# %%
print(test_target)
# Out:
# 10     0
# 75     1
# 57     1
# 63     1
# 30     0
# 136    2
# 38     0
# 61     1
# 35     0
# 23     0
# 77     1
# 108    2
# 103    2
# 45     0
# 148    2
# 91     1
# 96     1
# 114    2
# 51     1
# 144    2
# 132    2
# 41     0
# 128    2
# 130    2
# 2      0
# 60     1
# 78     1
# 84     1
# 43     0
# 87     1
# Name: variety, dtype: int64

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(test_target,predicted_target)
print(acc)
# Out:
# 1.0
